# %% [markdown]
# # Тема вычислительной работы
#
# **Лаборатория математики ФН1**
#
# | | |
# | --- | --- |
# | Студент | Фамилия И. О. |
# | Группа | ФН1-11Б |
# | Дисциплина | Численные методы |
# | Руководитель | должность, Фамилия И. О. |
# | Дата сдачи | ДД.ММ.ГГГГ |
#
# > Замените заголовки-заглушки своим текстом. Структура разделов менять нельзя.

# %% [markdown]
# ## 1. Постановка задачи
#
# Приведите строгую математическую формулировку. Например:
#
# $$\frac{\partial u}{\partial t} = a^2\frac{\partial^2 u}{\partial x^2},\qquad
# u(x, 0) = \varphi(x),\qquad u(0,t) = u(L,t) = 0.$$
#
# Укажите, что дано, что требуется найти и в каком смысле понимается решение.

# %% [markdown]
# ## 2. Метод решения
#
# Опишите алгоритм: расчётные формулы, условие устойчивости, порядок аппроксимации,
# оценку вычислительной сложности.

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams.update({"figure.figsize": (9, 5), "font.size": 12, "grid.alpha": 0.3})

# Параметры задачи вынесите в отдельную ячейку — «магических чисел» в коде быть не должно.
A = 1.0      # коэффициент температуропроводности
L = 1.0      # длина отрезка
T = 0.1      # время расчёта
N_X = 51     # узлов по пространству
N_T = 2000   # шагов по времени

# %% [markdown]
# ## 3. Реализация

# %%
def solve(a=A, length=L, t_end=T, n_x=N_X, n_t=N_T):
    """Краткое описание: что принимает, что возвращает."""
    raise NotImplementedError("Замените заглушку своей реализацией")

# %% [markdown]
# ## 4. Численный эксперимент
#
# Приведите таблицу сходимости и графики. У каждого графика должны быть
# подписаны оси и указаны единицы измерения.

# %%
# Таблица сходимости: измельчайте сетку и оценивайте наблюдаемый порядок точности
# p = log2(err[h] / err[h/2])

# %% [markdown]
# ## 5. Выводы
#
# 1. Сопоставьте наблюдаемый порядок точности с теоретической оценкой.
# 2. Укажите границы применимости метода.
# 3. Отметьте, что осталось за рамками работы.
#
# ## Литература
#
# 1. Самарский А. А. Теория разностных схем. — М.: Наука.
# 2. Калиткин Н. Н. Численные методы. — М.: Наука.
